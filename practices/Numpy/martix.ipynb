# %%
import numpy as np
var = np.matrix([[1,2],[3,4]])
print(var)
print(type(var))
# Out:
# [[1 2]
#  [3 4]]
# <class 'numpy.matrix'>

# %%
var1 = np.array([[1,2],[3,4]])
print(var1)
print(type(var1))
# Out:
# [[1 2]
#  [3 4]]
# <class 'numpy.ndarray'>

# %% [markdown]
# # Addition and subtraction is same in martrix and array but the multiplication is different

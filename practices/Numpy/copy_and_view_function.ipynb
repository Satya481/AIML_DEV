# %% [markdown]
# # copy

# %%
import numpy as np                  #copy the original data but changes made in copied data no changes will occur in original data 
var = np.array([1,2,3,4])
co = var.copy()
var[1]=
print("var :",var)
print("co:",co)
# Out:
# var : [1 8 3 4]
# co: [1 2 3 4]

# %%
var = np.array([1,2,3,4])             # view data does not creat new data but it shows the original data and if changed it will effect the original data 
vi = var.view()
print("var : ",var)
print("vi: ",vi)
# Out:
# var :  [1 2 3 4]
# vi:  [1 2 3 4]

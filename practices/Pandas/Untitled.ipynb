# %%
import pandas as pd
data = {"Name": ["John","Peter","Lisa"],
       "Age":[25,28,31],
       "Salary":[30000,50000,35000]}
data_frame = pd.DataFrame(data)
print(data_frame)
# Out:
#     Name  Age  Salary
# 0   John   25   30000
# 1  Peter   28   50000
# 2   Lisa   31   35000

# %%
data = pd.read_excel("02_02_XYScatter.xlsx")
print(data)
# Out:
#     Distance  Amount Spent
# 0          1            35
# 1          1            13
# 2          2            40
# 3          4            20
# 4          4            15
# 5          5            35
# 6         10            35
# 7         20            50
# 8         20            25
# 9         22            40
# 10        45            35
# 11        50            75
# 12        50           125
# 13        50            67
# 14        75            99
# 15        75           149
# 16        75           110
# 17        75           120
# 18        85           130
# 19        87            75
# 20        99           101
# 21       100           200
# 22       125           125
# 23       130           220
# 24       145           150
# 25       152           195

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Distance      26 non-null     int64
#  1   Amount Spent  26 non-null     int64
# dtypes: int64(2)
# memory usage: 548.0 bytes
# None

# %%
print(data.describe())
# Out:
#          Distance  Amount Spent
# count   26.000000     26.000000
# mean    57.961538     87.846154
# std     47.905307     60.957488
# min      1.000000     13.000000
# 25%     12.500000     35.000000
# 50%     50.000000     75.000000
# 75%     86.500000    125.000000
# max    152.000000    220.000000

# %%
data1 = pd.read_excel("ESD.xlsx")
print(data1.head(10))
print(data1.head(10))
print(data1.describe())
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

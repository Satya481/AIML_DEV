# %% [markdown]
# # Project: Predict if a student will pass an exam based on how many hours they studied.

# %% [markdown]
# 📊 Dataset:
#
# Hours Studied: [1, 2, 3, 4, 5, 6, 7]
#
# Passed (1 = Yes, 0 = No) : [0, 0, 0, 1, 1, 1, 1]

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
hours = np.array([1, 2, 3, 4, 5, 6, 7])
passed = np.array([0, 0, 0, 1, 1, 1, 1])

# %%
model = LogisticRegression()
model.fit(hours.reshape(-1,1),passed)
# Out:
# LogisticRegression()

# %%
hours=[[14]]
prediction = model.predict(hours)
print("Prediction for hour 14:", prediction[0])
# Out:
# Prediction for hour 14: 1

# %%
# 1. Make a smooth line for hours from 0 to 8
hours_range = np.linspace(0, 12, 100).reshape(-1, 1)
probs_range = model.predict_proba(hours_range)[:, 1]

# %%
# 2. Plotting
plt.figure(figsize=(15, 5))

# %%
# Smooth prediction curve
plt.plot(hours_range, probs_range, color='green', linewidth=2, label='Predicted Probability')

# Red dots for new students
plt.scatter(new_students, predicted_probs, color='red', s=100, label='New Students')
decision_boundary = -model.intercept_[0] / model.coef_[0][0]
plt.axvline(x=decision_boundary, color='blue', linestyle='--', label='Decision Boundary')

# Labels and decorations
plt.xlabel('Hours Studied')
plt.ylabel('Probability of Passing')
plt.title('Student Pass Probability vs. Hours Studied')
plt.legend()
plt.grid(True)
plt.show()
